# %% [markdown]
# # Table of Contents
#
# - [General Overview](#general-overview)
# - [Business Understanding](#business-understanding)
# - [Data Understanding](#data-understanding)
# - [EDA](#eda)
# - [Creating Series](#Creating-Series)
# - [Stationary Check](#stationary-check)
# - [Splitting Data](#Splitting-Data)
# - [Model Parameters Grid Search](#model-parameters-grid-search)
#     - [Arima Model Grid-Search](#Arima-Model-Grid-Search)
#     - [Sarimax Model Grid-Search](#Sarimax-Model-Grid-Search)
# - [Model Parameters](#Model-Parameters)
# - [Modeling](#modeling)
# - [Forecast](#Forecast)
# - [ROI](#ROI)
# - [Interpreting Results](#interpreting-results)
# - [Recommendations](#recommendations)
# - [Next Steps](#next-steps)
# - [Repository File Structure](#repository-file-structure)

# %% [markdown]
# <a id='general-overview'></a>
# # General Overview

# %% [markdown]
# <a id='business-understanding'></a>
# # Business Understanding

# %% [markdown]
# <a id='data-understanding'></a>
# # Data Understanding
#
# **Data info:**
#
#     RegiondID - zillow's own ID
#     RegionName - Zipcodes, renamed to zipcode
#     City - City
#     State - State
#     Metro - Metropolitan area
#     CountyName- - County
#     SizeRank - ranking of zipcode sizes
#     The rest - datas and their median monthly house sales

# %%
#"The expectations of life depend upon diligence; the mechanic that would perfect his work must first sharpen his tools."
#- Confucius

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns


from sklearn.decomposition import PCA


import warnings
warnings.filterwarnings('ignore')


import pandas as pd
import numpy as np
# pd.set_option('display.max_rows', 1000)
from datetime import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import itertools
import numpy as np
from joblib import Parallel, delayed
from matplotlib.ticker import StrMethodFormatter

# %%
# Creating DataFrame
df = pd.read_csv('zillow_data.zip')
df = df.rename(columns={'RegionName': 'zipcode'})
# Creating ROI column
df['22_year_pct_change'] = ((df['2018-04'] / df['1996-04']) - 1)

# %%
df.columns
#last columns are in a "Wide" format
# Out:
# Index(['RegionID', 'zipcode', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06',
#        ...
#        '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01',
#        '2018-02', '2018-03', '2018-04', '22_year_pct_change'],
#       dtype='object', length=273)

# %%
df.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        14723 non-null  object
#  1   State       14723 non-null  object
#  2   Metro       13680 non-null  object
#  3   CountyName  14723 non-null  object
# dtypes: object(4)
# memory usage: 460.2+ KB

# %%
df.describe()
# Out:
#             RegionID       zipcode      SizeRank       1996-04       1996-05  \
# count   14723.000000  14723.000000  14723.000000  1.368400e+04  1.368400e+04
# mean    81075.010052  48222.348706   7362.000000  1.182991e+05  1.184190e+05
# std     31934.118525  29359.325439   4250.308342  8.600251e+04  8.615567e+04
# min     58196.000000   1001.000000      1.000000  1.130000e+04  1.150000e+04
# 25%     67174.500000  22101.500000   3681.500000  6.880000e+04  6.890000e+04
# 50%     78007.000000  46106.000000   7362.000000  9.950000e+04  9.950000e+04
# 75%     90920.500000  75205.500000  11042.500000  1.432000e+05  1.433000e+05
# max    753844.000000  99901.000000  14723.000000  3.676700e+06  3.704200e+06
#
#             1996-06       1996-07       1996-08       1996-09       1996-10  \
# count  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04  1.368400e+04
# mean   1.185374e+05  1.186531e+05  1.187803e+05  1.189275e+05  1.191205e+05
# std    8.630923e+04  8.646795e+04  8.665094e+04  8.687208e+04  8.715185e+04
# min    1.160000e+04  1.180000e+04  1.180000e+04  1.200000e+04  1.210000e+04
# 25%    6.910000e+04  6.920000e+04  6.937500e+04  6.950000e+04  6.960000e+04
# 50%    9.970000e+04  9.970000e+04  9.980000e+04  9.990000e+04  9.995000e+04
# 75%    1.432250e+05  1.432250e+05  1.435000e+05  1.437000e+05  1.439000e+05
# max    3.729600e+06  3.754600e+06  3.781800e+06  3.813500e+06  3.849600e+06
#
#        ...       2017-08       2017-09       2017-10       2017-11  \
# count  ...  1.472300e+04  1.472300e+04  1.472300e+04  1.472300e+04
# mean   ...  2.748658e+05  2.764646e+05  2.780332e+05  2.795209e+05
# std    ...  3.614678e+05  3.627563e+05  3.644610e+05  3.656003e+05
# min    ...  1.450000e+04  1.470000e+04  1.480000e+04  1.450000e+04
# 25%    ...  1.275000e+05  1.282000e+05  1.287000e+05  1.292500e+05
# 50%    ...  1.896000e+05  1.905000e+05  1.914000e+05  1.925000e+05
# 75%    ...  3.066500e+05  3.085000e+05  3.098000e+05  3.117000e+05
# max    ...  1.870350e+07  1.860530e+07  1.856940e+07  1.842880e+07
#
#             2017-12       2018-01       2018-02       2018-03       2018-04  \
# count  1.472300e+04  1.472300e+04  1.472300e+04  1.472300e+04  1.472300e+04
# mean   2.810953e+05  2.826571e+05  2.843687e+05  2.865114e+05  2.880399e+05
# std    3.670454e+05  3.695727e+05  3.717739e+05  3.724612e+05  3.720544e+05
# min    1.430000e+04  1.410000e+04  1.390000e+04  1.380000e+04  1.380000e+04
# 25%    1.299000e+05  1.306000e+05  1.310500e+05  1.319500e+05  1.324000e+05
# 50%    1.934000e+05  1.941000e+05  1.950000e+05  1.967000e+05  1.981000e+05
# 75%    3.134000e+05  3.151000e+05  3.168500e+05  3.188500e+05  3.211000e+05
# max    1.830710e+07  1.836590e+07  1.853040e+07  1.833770e+07  1.789490e+07
#
#        22_year_pct_change
# count        13684.000000
# mean             1.325605
# std              0.866019
# min             -0.532609
# 25%              0.785691
# 50%              1.139484
# 75%              1.619833
# max             11.189940
#
# [8 rows x 269 columns]

# %% [markdown]
# <a id='eda'></a>
# # EDA

# %%
# Checking for nulls
null_index = []
null_values = []
for index, value in df.isna().sum().items():
    if value != 0:
        null_index.append(index)
        null_values.append(value)       
print(f'There are {len(null_index)} columns with nulls\nRanging from {min(null_values)} to {max(null_values)} Nulls')
# Out:
# There are 221 columns with nulls
# Ranging from 56 to 1043 Nulls

# %%
df.dropna(inplace=True)
#Opted for dropping na's because represent 13% loss of total and interpolation or forward/backward filling

# %%
#[14723 rows x 272 columns]> / 12895 rows × 272 columns
melted_df = pd.melt(df, id_vars=['RegionID', 'zipcode', 'City', 'State', 'Metro',
                                 'CountyName', 'SizeRank','22_year_pct_change'],
                    var_name='Date', value_name='MedianHousingSales')

# 'MedianHousingSales' contains corresponding values for each date and zipcode combination

# %%
melted_df
# Out:
#          RegionID  zipcode          City State              Metro CountyName  \
# 0           84654    60657       Chicago    IL            Chicago       Cook
# 1           90668    75070      McKinney    TX  Dallas-Fort Worth     Collin
# 2           91982    77494          Katy    TX            Houston     Harris
# 3           84616    60614       Chicago    IL            Chicago       Cook
# 4           93144    79936       El Paso    TX            El Paso    El Paso
# ...           ...      ...           ...   ...                ...        ...
# 3417170     99032    97028  Rhododendron    OR           Portland  Clackamas
# 3417171     58333     1338      Ashfield    MA    Greenfield Town   Franklin
# 3417172     59107     3293     Woodstock    NH          Claremont    Grafton
# 3417173     75672    40404         Berea    KY           Richmond    Madison
# 3417174     95851    89155      Mesquite    NV          Las Vegas      Clark
#
#          SizeRank  22_year_pct_change     Date  MedianHousingSales
# 0               1            2.083782  1996-04            334200.0
# 1               2            0.365295  1996-04            235700.0
# 2               3            0.567966  1996-04            210400.0
# 3               4            1.623971  1996-04            498100.0
# 4               5            0.571798  1996-04             77300.0
# ...           ...                 ...      ...                 ...
# 3417170     14717            1.564611  2018-04            349300.0
# 3417171     14719            1.212474  2018-04            209300.0
# 3417172     14720            1.435814  2018-04            225800.0
# 3417173     14721            1.336252  2018-04            133400.0
# 3417174     14723            1.024943  2018-04            357200.0
#
# [3417175 rows x 10 columns]

# %%
# Reshape
reshaped_df = df.melt(id_vars=['RegionID', 'zipcode', 'City', 'State', 'Metro',
                               'CountyName', 'SizeRank', '22_year_pct_change'],
                      var_name='Date', value_name='MedianHousingSales')

#'Date' column to datetime format
reshaped_df['Date'] = pd.to_datetime(reshaped_df['Date'], format='%Y-%m')

# Pivot
final_df = reshaped_df.pivot_table(index=['Date', 'RegionID', 'zipcode', 'City', 'State', 'Metro',
                                          'CountyName', 'SizeRank', '22_year_pct_change'],
                                   values='MedianHousingSales')

# Reset the index to make 'Date' and other columns separate columns
final_df = final_df.reset_index()

# %%
final_df
# Out:
#               Date  RegionID  zipcode          City State           Metro  \
# 0       1996-04-01     58196     1001        Agawam    MA     Springfield
# 1       1996-04-01     58197     1002       Amherst    MA     Springfield
# 2       1996-04-01     58200     1005         Barre    MA       Worcester
# 3       1996-04-01     58201     1007   Belchertown    MA     Springfield
# 4       1996-04-01     58202     1008     Blandford    MA     Springfield
# ...            ...       ...      ...           ...   ...             ...
# 3417170 2018-04-01    677175    84009  South Jordan    UT  Salt Lake City
# 3417171 2018-04-01    698721    86005     Flagstaff    AZ       Flagstaff
# 3417172 2018-04-01    738092    97003     Beaverton    OR        Portland
# 3417173 2018-04-01    753843    97703          Bend    OR            Bend
# 3417174 2018-04-01    753844    29486   Summerville    SC      Charleston
#
#          CountyName  SizeRank  22_year_pct_change  MedianHousingSales
# 0           Hampden      5851            0.977011            113100.0
# 1         Hampshire      4200            1.194410            161000.0
# 2         Worcester     11214            1.140640            103100.0
# 3         Hampshire      6851            1.028486            133400.0
# 4           Hampden     14548            0.822979            117500.0
# ...             ...       ...                 ...                 ...
# 3417170   Salt Lake      4654            1.444182            413800.0
# 3417171    Coconino      5836            2.119746            393400.0
# 3417172  Washington      3950            1.587838            344700.0
# 3417173   Deschutes      2804            2.125336            581000.0
# 3417174  Dorchester      3188            1.648383            188300.0
#
# [3417175 rows x 10 columns]

# %%
def microplot(data, X, y_sort, limit=20, **kwargs):
    '''
    data : dataframe
    x : x axis value
    y_sort : y axis values and what the data gets sorted by
    limit : limt for x output, default is 20
    '''
    
    df_sorted = data.sort_values(by=y_sort, ascending=False, inplace=False)[:limit]
    x_order = df_sorted[X].values.tolist()
    fig, ax = plt.subplots(figsize=(15,8))
    ax = sns.barplot(x= X, y= y_sort, data=df_sorted, palette= 'YlOrRd_r', order=x_order, **kwargs)
    ax.set_title(f'{y_sort} vs. {X}', fontsize=15)
    ax.set_xlabel(data[X].name, fontsize=15)
    ax.set_ylabel(y_sort, fontsize=15)

# %%
microplot(df, 'zipcode', '22_year_pct_change')

# %%
def macroplot(data, group, y, limit=None ,**kwargs):
    '''
    data : dataframe
    group : groupby column
    y : y column or target
    limit : limit for x output
    '''
    states_df = data.groupby(by= group)[y].mean()
    df_sorted = states_df.sort_values(ascending=False)[:limit]
    x_order = df_sorted.index.tolist()
        
    fig, ax = plt.subplots(figsize=(18,8))
    ax = sns.barplot(x=df_sorted.index, y= df_sorted.values, palette= 'YlOrRd_r', order=x_order, **kwargs)
    ax.set_title(f'{y} vs. {group}', fontsize=15)
    ax.set_xlabel(group, fontsize=15)
    ax.set_ylabel(y, fontsize=15)

# %%
macroplot(df, 'State', '22_year_pct_change')

# %%
macroplot(final_df, 'State', 'MedianHousingSales')

# %% [markdown]
# DC has the highest Median House Sale and the highest ROI over 22 years

# %% [markdown]
# <a id='Creating-Series'></a>
# # Creating Series

# %%
selected_states = ['DC']
dc_df = final_df[final_df['State'].isin(selected_states)]

# creating percent change or ROI
dc_df['PercentChange'] = dc_df.groupby('zipcode')['MedianHousingSales'].pct_change() *100

# Series
limited_df = dc_df.groupby('Date')['MedianHousingSales'].median()
limited_df = limited_df.resample('MS').median()

# Creating various transformations
diff_df = limited_df.diff().dropna()
diff_df2 = limited_df.diff().diff().dropna()
sqrt_df = np.sqrt(limited_df)
log_df = np.log(limited_df)
log_dff = log_df.diff().diff().dropna()

# %% [markdown]
# <a id='stationary-check'></a>
# # Stationary Check

# %%
# Function to check if data is stationary
def stationary(*args):
    pv = []
    for data in args:
        if adfuller(data)[1]< .05:
            print(f'{adfuller(data)[1]< .05} With a P-Value of {adfuller(data)[1]}\n')
            pv.append(adfuller(data)[1])
        else:
            print(f'{False}\n')
    if pv:
        print(f'Lowest P-Value: {min(pv)}')
stationary(limited_df, diff_df, diff_df2, sqrt_df, log_df, log_dff)
# Out:
# False
#
# False
#
# True With a P-Value of 1.1627181922527525e-09
#
# False
#
# False
#
# True With a P-Value of 1.0008897959519989e-08
#
# Lowest P-Value: 1.1627181922527525e-09

# %%
fig, ax = plt.subplots(figsize=(4,2))
limited_df.plot();

# %%
fig, ax = plt.subplots(figsize=(4,2))
log_df.plot();

# %%
fig, ax = plt.subplots(figsize=(6,4))
diff_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(figsize=(6,4))
diff_df2.plot();

# %%
plot_acf(limited_df, lags=50);
plot_pacf(limited_df,lags=15, method='ywm');

# %%
plot_acf(diff_df2, lags=50);
plot_pacf(diff_df2,lags=50, method='ywm');

# %% [markdown]
# <a id='Splitting-Data'></a>
# # Splitting Data

# %%
def ttsplit(data):
        cutoff = round(data.shape[0]* .9)
        # creating train and test
        train = data[:cutoff]
        test = data[cutoff:]
        return(train, test)
train, test = ttsplit(limited_df)

# %% [markdown]
# <a id='model-parameters-grid-search'></a>
# # Model Parameters Grid Search

# %% [markdown]
# <a id='Arima-Model-Grid-Search'></a>
# ## Arima Model Grid Search

# %%
def pdq_fitting(data, convergenceWarning=False, summary=False)
    '''
    Function loops through finding the best p, d, q sequence
    convergenceWarning: True = ignore convergence warnings, False = don't ignore
    Summary: print for each pdq check
    '''
    results = []

    for p in range(5):
        for d in range(3):
            for q in range(5):
                # try, except to catch warnings and errors
                try:
                    # Catching Warnings
                    with warnings.catch_warnings(record=True) as warn:
                        if convergenceWarning:    
                            warnings.simplefilter("ignore", ConvergenceWarning)
                            
                        model = ARIMA(data, order=(p, d, q)).fit()
                    # If there is a warning, remove
                    if warn: 
                        if summary:
                            print(f"\n\033[1m\033[93m{warn[0].message}\nWarning while fitting ARIMA model with p={p}, d={d}, q={q}. Skipping\033[0m")
                            print(f"{'-'*100}\n")
                        else:
                            continue
                    # No Warning, keep
                    else:    
                        aic_score = model.aic
                        results.append((aic_score, p, d, q))
                        if summary:
                            print("P of: ",p)
                            print("d of: ",d)
                            print("q of: ",q)
                            print("AIC score: ", aic_score)
                            print(f"{'-'*100}\n")

                except Exception as e:
                    print(f"\033[1m\033[91m{e}\nFailed to fit ARIMA model with p={p}, d={d}, q={q}. Skipping\033[0m")
                    print(f"{'-'*100}\n")

    results.sort()
    print(f"Best p, d, q for lowest AIC score: {results[0][0]}")
    print("P of: ", results[0][1])
    print("d of: ", results[0][2])
    print("q of: ", results[0][3])

# %% [markdown]
# <a id='Sarimax-Model-Grid-Search'></a>
# ## Sarimax Model Grid Search

# %%
def pdqs_fitting(data, S, n, convergenceWarning=False, summary=False, n_jobs=-1, ):
    
    # replacing for loop with array
    options = np.array(list(itertools.product(np.arange(n), repeat=6)))
    results = []

    def fit_model(p, d, q, P, D, Q, S, summary, convergenceWarning):
        # try, except to catch warnings and errors
        try:
            # Catching Warnings
            warnings.filterwarnings("ignore", message= "Example message")
           
            with warnings.catch_warnings(record=True) as warn:
                if convergenceWarning: 
                    warnings.simplefilter("ignore", ConvergenceWarning)  
                
                model = SARIMAX(data, order=(p, d, q), seasonal_order=(P, D, Q, S),
                               enforce_stationarity=False, enforce_invertibility=False).fit()
                           
                y_hat_train = model.predict(typ='levels')
                y_hat_test = model.predict(start=test.index[0], end=test.index[-1],typ='levels')

            # If there is a warning, remove
            if warn: 
                if summary:
                    print(f"\n\033[1m\033[93m{warn[0].message}\nWarning while fitting ARIMA model with p={p}, d={d}, q={q}, P={P}, D={D}, Q={Q}, s={S}. Skipping\033[0m")
                    print(f"{'-'*100}\n")
                else:
                    pass
            # No Warning, keep
            else:                
                aic_score = model.aic
                rmse = np.sqrt(mean_squared_error(test, y_hat_test))
                
                if summary:
                    sys.stdout.write(f"({p},{d},{q})\n({P},{D},{Q},{S})")
                    print("AIC score: ", aic_score)
                    print(f"{'-'*100}\n")
                return {"aic" : (aic_score, (p, d, q), (P, D, Q, S)), "rmse" : (rmse , (p, d, q), (P, D, Q, S)),
                       "best" : (aic_score + rmse, (p, d, q), (P, D, Q, S), aic_score, rmse)}

        except Exception as e:
            print(f"\033[1m\033[91m{e}\nFailed to fit ARIMA model with p={p}, d={d}, q={q}, d={d}, P={P}, D={D}, Q={Q}, s={S}. Skipping\033[0m")
            print(f"{'-'*100}\n")
            
    # running in parallel
    results = Parallel(n_jobs=n_jobs, verbose=1)(
        delayed(fit_model)(p, d, q, P, D, Q, S, summary, convergenceWarning)
        for p, d, q, P, D, Q in options)
  

    # Final output
    new_results = [r for r in results if r is not None] 
    aic_results = [r['aic'] for r in new_results]
    rmse_results = [r['rmse'] for r in new_results]
    best = [r['best'] for r in new_results]
    
    def printer(results, r_type, best_score=None):
        results.sort()
        print(f"Best p, d, q and P, D, Q, s for lowest {r_type}: {results[0][0]}")
        if best_score:
            print(f"AIC: {results[0][3]}\nRMSE: {results[0][4]}")
        print(f"pdq= {results[0][1]}")
        print(f"PDQs= {results[0][2]}\n")
        print(f'{results[0][1]}, {results[0][2]}')
                     
    printer(rmse_results,'RMSE')
    printer(aic_results,'AIC')
    printer(best,'avg. AIC and RMSE', True)
#     return (aic_results, rmse_results, best)

# %%
pdq_fitting(train, summary=False)
# Out:
# Best p, d, q for lowest AIC score: 3814.128456582471
# P of:  4
# d of:  0
# q of:  4

# %%
pdqs_fitting(train, 12,3)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 729 out of 729 | elapsed:  6.0min finished
# Best p, d, q and P, D, Q, s for lowest RMSE: 3161.090631490058
# pdq= (2, 1, 1)
# PDQs= (2, 1, 0, 12)
#
# (2, 1, 1), (2, 1, 0, 12)
# Best p, d, q and P, D, Q, s for lowest AIC: 3195.0387914868033
# pdq= (0, 2, 2)
# PDQs= (1, 2, 2, 12)
#
# (0, 2, 2), (1, 2, 2, 12)
# Best p, d, q and P, D, Q, s for lowest avg. AIC and RMSE: 6463.089204247708
# AIC: 3301.9985727576504
# RMSE: 3161.090631490058
# pdq= (2, 1, 1)
# PDQs= (2, 1, 0, 12)
#
# (2, 1, 1), (2, 1, 0, 12)
# ([(3195.0387914868033, (0, 2, 2), (1, 2, 2, 12)),
#   (3207.810130503031, (2, 2, 1), (2, 2, 0, 12)),
#   (3211.4114406001886, (2, 2, 0), (2, 2, 1, 12)),
#   (3212.3848083869366, (2, 2, 0), (2, 2, 0, 12)),
#   (3215.2607720396204, (0, 2, 2), (0, 2, 2, 12)),
#   (3217.232267071645, (2, 1, 1), (2, 2, 0, 12)),
#   (3217.4720312915397, (2, 1, 0), (2, 2, 0, 12)),
#   (3217.582434822484, (2, 1, 1), (2, 2, 1, 12)),
#   (3217.7839862728392, (2, 1, 0), (2, 2, 1, 12)),
#   (3218.2260854927654, (2, 1, 2), (2, 2, 0, 12)),
#   (3218.9358065177166, (2, 1, 1), (2, 2, 2, 12)),
#   (3221.403876921827, (2, 1, 1), (1, 2, 2, 12)),
#   (3221.9199914224837, (1, 2, 1), (1, 2, 2, 12)),
#   (3236.2042204646486, (2, 2, 0), (1, 2, 2, 12)),
#    100050.41794087389),
#   (103608.37230316893,
#    (1, 2, 1),
#    (2, 1, 0, 12),
#    3312.7282645163705,
#    100295.64403865256),
#   (105074.14014868099,
#    (0, 1, 1),
#    (1, 2, 0, 12),
#    3806.260156429624,
#    101267.87999225137),
#   (105978.46479175969,
#    (1, 0, 0),
#    (0, 2, 0, 12),
#    4258.988781006701,
#    101719.47601075299),
#   (106620.96221282368,
#    (1, 2, 0),
#    (2, 1, 0, 12),
#    3317.862868694412,
#    103303.09934412927),
#   (106623.16346434169,
#    (0, 2, 2),
#    (1, 2, 0, 12),
#    3536.3431797378207,
#    103086.82028460388),
#   (107553.63529899232,
#    (1, 1, 1),
#    (0, 2, 1, 12),
#    3549.605978795462,
#    104004.02932019686),
#   (108484.50903309646,
#    (2, 2, 2),
#    (2, 1, 0, 12),
#    3296.887937496517,
#    105187.62109559994),
#   (110881.58730842071,
#    (0, 0, 1),
#    (2, 2, 1, 12),
#    5077.194556708921,
#    105804.3927517118),
#   (111574.98454565024,
#    (0, 2, 2),
#    (1, 1, 1, 12),
#    3471.649554499621,
#    108103.33499115062),
#   (112614.1522457622,
#    (0, 0, 1),
#    (2, 1, 1, 12),
#    6006.1839269753955,
#    106607.9683187868),
#   (115840.84046226414,
#    (1, 2, 0),
#    (1, 1, 2, 12),
#    3320.7010298774685,
#    112520.13943238667),
#   (116737.78311748877,
#    (0, 1, 0),
#    (0, 2, 0, 12),
#    4239.46996141062,
#    112498.31315607815),
#   (122291.44050442915,
#    (0, 1, 1),
#    (0, 2, 0, 12),
#    4083.6699850291725,
#    118207.77051939997),
#   (125932.85196977525,
#    (0, 1, 2),
#    (0, 2, 0, 12),
#    3940.556750054622,
#    121992.29521972063),
#   (130694.30856966513,
#    (1, 2, 1),
#    (1, 1, 1, 12),
#    3493.438223785616,
#    127200.8703458795),
#   (134650.19206242898,
#    (0, 2, 2),
#    (2, 1, 0, 12),
#    3319.310298098687,
#    131330.8817643303),
#   (136530.27031437718,
#    (0, 2, 1),
#    (1, 2, 1, 12),
#    3459.529469418572,
#    133070.7408449586),
#   (137989.06297139378,
#    (0, 0, 2),
#    (2, 2, 2, 12),
#    4978.787037751721,
#    133010.27593364206),
#   (138811.47436067864,
#    (0, 0, 0),
#    (2, 2, 1, 12),
#    5135.0657744790215,
#    133676.40858619963),
#   (139428.2015045812,
#    (1, 2, 1),
#    (1, 1, 0, 12),
#    3514.256986644139,
#    135913.94451793705),
#   (141229.2939626579,
#    (2, 2, 1),
#    (1, 2, 0, 12),
#    3434.9917702027597,
#    137794.30219245513),
#   (143557.83837315405,
#    (2, 1, 0),
#    (0, 2, 0, 12),
#    3806.419932143648,
#    139751.4184410104),
#   (144951.02459316613,
#    (2, 2, 1),
#    (1, 2, 1, 12),
#    3433.000075608602,
#    141518.02451755753),
#   (145941.02811708246,
#    (0, 2, 1),
#    (2, 2, 1, 12),
#    3280.970779820602,
#    142660.05733726185),
#   (146877.5816121525,
#    (1, 2, 0),
#    (1, 1, 1, 12),
#    3516.751281343135,
#    143360.83033080937),
#   (147716.82985073817,
#    (2, 1, 1),
#    (0, 2, 0, 12),
#    3805.4667634269395,
#    143911.36308731124),
#   (147920.50042191296,
#    (0, 0, 2),
#    (1, 0, 1, 12),
#    6888.3981475131895,
#    141032.10227439977),
#   (148393.9717128636,
#    (0, 2, 1),
#    (1, 2, 2, 12),
#    3236.7633250782305,
#    145157.20838778536),
#   (148754.27052635184,
#    (2, 2, 0),
#    (1, 2, 0, 12),
#    3433.2981195450393,
#    145320.9724068068),
#   (149294.28220034743,
#    (1, 2, 0),
#    (1, 1, 0, 12),
#    3515.6985233457713,
#    145778.58367700165),
#   (152538.3228576447,
#    (0, 2, 1),
#    (2, 2, 0, 12),
#    3283.054743558143,
#    149255.26811408656),
#   (154887.21605620527,
#    (2, 2, 0),
#    (1, 2, 1, 12),
#    3431.4559952232803,
#    151455.760060982),
#   (155193.55556625998,
#    (2, 1, 2),
#    (0, 2, 0, 12),
#    3778.6233608525154,
#    151414.93220540747),
#   (156700.41339108034,
#    (1, 1, 2),
#    (0, 2, 0, 12),
#    3776.848358499532,
#    152923.5650325808),
#   (182448.92910708554,
#    (2, 2, 0),
#    (2, 2, 1, 12),
#    3211.4114406001886,
#    179237.51766648536),
#   (182819.48564779517,
#    (2, 2, 0),
#    (1, 2, 2, 12),
#    3236.2042204646486,
#    179583.2814273305),
#   (183593.44790170353,
#    (0, 2, 2),
#    (1, 2, 1, 12),
#    3416.617905369368,
#    180176.82999633416),
#   (185985.5733242007,
#    (1, 2, 2),
#    (1, 2, 0, 12),
#    3461.7633371806323,
#    182523.80998702007),
#   (186514.58440745313,
#    (1, 1, 1),
#    (0, 2, 0, 12),
#    3830.3062946866094,
#    182684.27811276654),
#   (188930.22155285586,
#    (1, 2, 2),
#    (1, 2, 1, 12),
#    3418.3455338896806,
#    185511.87601896617),
#   (189307.20345617738,
#    (2, 2, 0),
#    (2, 2, 0, 12),
#    3212.3848083869366,
#    186094.81864779044),
#   (200948.1480417166,
#    (2, 2, 2),
#    (2, 2, 1, 12),
#    3259.0313707489704,
#    197689.11667096763),
#   (201094.3454004009,
#    (2, 2, 2),
#    (2, 2, 0, 12),
#    3258.0728490565634,
#    197836.27255134433),
#   (204273.40127929425,
#    (1, 1, 0),
#    (0, 2, 0, 12),
#    3892.866500942311,
#    200380.53477835195),
#   (208731.64369703276,
#    (1, 2, 1),
#    (1, 2, 0, 12),
#    3462.7823796939856,
#    205268.86131733877),
#   (209387.53675767287,
#    (1, 2, 1),
#    (1, 2, 1, 12),
#    3439.248301551408,
#    205948.28845612146),
#   (214437.4733621996,
#    (0, 2, 2),
#    (1, 2, 2, 12),
#    3195.0387914868033,
#    211242.43457071282),
#   (215777.78606060377,
#    (1, 2, 2),
#    (2, 2, 0, 12),
#    3277.186566506508,
#    212500.59949409726),
#   (223126.88269564408,
#    (1, 2, 1),
#    (1, 2, 2, 12),
#    3221.9199914224837,
#    219904.9627042216),
#   (226367.75006831612,
#    (1, 2, 0),
#    (1, 2, 0, 12),
#    3464.981590634723,
#    222902.76847768138),
#   (234919.3898684026,
#    (1, 2, 0),
#    (1, 2, 1, 12),
#    3462.7283835937087,
#    231456.6614848089),
#   (243975.44241165035,
#    (0, 0, 2),
#    (0, 1, 2, 12),
#    5885.475443066685,
#    238089.96696858367),
#   (245555.593192254,
#    (1, 2, 1),
#    (2, 2, 1, 12),
#    3237.19284368842,
#    242318.40034856557),
#   (250311.69033493454,
#    (1, 2, 0),
#    (1, 2, 2, 12),
#    3245.33223165864,
#    247066.3581032759),
#   (254421.76273612306,
#    (1, 2, 1),
#    (2, 2, 0, 12),
#    3238.0000172504333,
#    251183.76271887263),
#   (255770.82662775397,
#    (0, 0, 1),
#    (0, 1, 2, 12),
#    5914.696461804492,
#    249856.13016594946),
#   (263831.58617155056,
#    (1, 2, 0),
#    (2, 2, 2, 12),
#    3240.4743559246353,
#    260591.11181562595),
#   (267821.40521853126,
#    (2, 2, 2),
#    (0, 2, 0, 12),
#    3779.011014696493,
#    264042.39420383476),
#   (269926.7962235516,
#    (1, 2, 2),
#    (0, 2, 0, 12),
#    3780.7628147824935,
#    266146.0334087691),
#   (271945.6133817877,
#    (0, 2, 2),
#    (0, 2, 0, 12),
#    3781.533258605393,
#    268164.0801231823),
#   (272754.18738597026,
#    (1, 2, 0),
#    (2, 2, 1, 12),
#    3240.311584394284,
#    269513.87580157595),
#   (277526.1825343419,
#    (0, 2, 2),
#    (2, 2, 0, 12),
#    3304.6764351560846,
#    274221.5060991858),
#   (279455.5113262224,
#    (0, 2, 2),
#    (2, 2, 1, 12),
#    3306.0320036484645,
#    276149.4793225739),
#   (282809.8413165504,
#    (1, 2, 0),
#    (2, 2, 0, 12),
#    3241.31254995062,
#    279568.5287665998),
#   (283005.9727687411,
#    (1, 2, 1),
#    (0, 2, 0, 12),
#    3806.220337436346,
#    279199.7524313047),
#   (284963.1612560762,
#    (2, 2, 1),
#    (0, 2, 0, 12),
#    3798.6027011360457,
#    281164.55855494016),
#   (286126.4292560696,
#    (1, 2, 0),
#    (0, 2, 0, 12),
#    3836.6821007054386,
#    282289.74715536414),
#   (287249.3753730376,
#    (2, 2, 0),
#    (0, 2, 0, 12),
#    3797.064589267445,
#    283452.31078377017),
#   (289529.80743966077,
#    (0, 2, 1),
#    (0, 2, 0, 12),
#    3811.41487108048,
#    285718.3925685803),
#   (297866.36999054614,
#    (0, 2, 0),
#    (0, 2, 0, 12),
#    3883.9245269805133,
#    293982.44546356564),
#   (570534.774187477,
#    (0, 0, 2),
#    (0, 1, 1, 12),
#    7351.7829481699755,
#    563182.991239307),
#   (598759.3616648715,
#    (0, 0, 1),
#    (0, 1, 1, 12),
#    7387.925144025106,
#    591371.4365208463),
#   (616952.102589822,
#    (0, 0, 1),
#    (0, 0, 1, 12),
#    6234.937396243311,
#    610717.1651935787),
#   (617116.2998831696,
#    (0, 0, 2),
#    (0, 0, 1, 12),
#    6896.724995644559,
#    610219.574887525),
#   (629621.7866608888,
#    (0, 0, 0),
#    (0, 0, 1, 12),
#    6330.52642005226,
#    623291.2602408365),
#   (727043.3106163758,
#    (0, 0, 2),
#    (0, 0, 0, 12),
#    6543.994233811496,
#    720499.3163825643),
#   (734903.2519156962,
#    (0, 0, 1),
#    (0, 0, 0, 12),
#    6608.611773375753,
#    728294.6401423204),
#   (743426.9273798269,
#    (0, 0, 0),
#    (0, 0, 2, 12),
#    10270.635926399835,
#    733156.291453427),
#   (744524.7367246117,
#    (0, 0, 0),
#    (0, 0, 0, 12),
#    6808.1573518274245,
#    737716.5793727842),
#   (1470584.398932471,
#    (0, 0, 2),
#    (2, 2, 1, 12),
#    4994.391734560207,
#    1465590.0071979107),
#   (89989094.79495357,
#    (0, 0, 0),
#    (1, 1, 1, 12),
#    6650.22919529313,
#    89982444.56575827),
#   (158347619.63774174,
#    (0, 0, 2),
#    (1, 1, 1, 12),
#    6417.208443471904,
#    158341202.42929828),
#   (185930059.78789744,
#    (0, 0, 1),
#    (1, 1, 1, 12),
#    6471.235519558595,
#    185923588.55237788)])

# %% [markdown]
# <a id='Model-Parameters'></a>
# # Model parameters
#
# RMSE and AIC summed and averaged is not used as it is the same as the lowest RMSE score
#
#      ARIMA            SARIMAX - AIC     SARIMAX - RMSE
#  --------------
#     p of: 4             p of: 0            p of: 2
#     d of: 0             d of: 2            d of: 1
#     q of: 4             q of: 2            q of: 1
#                         P of: 1            P of: 2
#                         D of: 2            D of: 1
#                         Q of: 2            Q of: 0
#                         s of: 12           s of: 12

# %% [markdown]
# <a id='modeling'></a>
# # Modeling

# %%
def prediction_model(**kwargs):
    fig, ax = plt.subplots(figsize=(20,12))
    ax.plot(train, label='train')
    ax.plot(test, label='test')
    
    for label, model in kwargs.items():
        y_hat_test = model.predict(start=test.index[0], end=test.index[-1],typ='levels')
        ax.plot(y_hat_test, label=label)
        
    ax.set_xlabel('Year', fontsize=20)
    ax.set_ylabel('Median House Sales', fontsize=20)
    ax.set_title('Predicting Median House Sales each Year', fontsize=20)
    ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
    ax.tick_params(axis='both', which='major', labelsize=15);
    plt.legend()

# %% [markdown]
# ### Arima Model

# %%
def arima_performance(data, pdq):
    '''
    pdq : (p,d,q)
    '''
    arma = ARIMA(data,order= pdq).fit()
    print(arma.mle_retvals)
    print(arma.summary())
    arma.plot_diagnostics(figsize=(16, 8))
    return arma
arima_model = arima_performance(train, (4,0,4))
# Out:
# {'fopt': 7.970858102064014, 'gopt': array([ 7.99359144e-10, -7.52418572e-05, -1.99839688e-02,  1.14568840e-02,
#         2.31334560e-03,  1.30925910e-03, -3.97641129e-03,  5.59949669e-03,
#         1.70126491e-03,  1.89400052e-04]), 'fcalls': 748, 'warnflag': 1, 'converged': False, 'iterations': 50}
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     MedianHousingSales   No. Observations:                  238
# Model:                 ARIMA(4, 0, 4)   Log Likelihood               -1897.064
# Date:                Fri, 12 May 2023   AIC                           3814.128
# Time:                        10:54:08   BIC                           3848.851
# Sample:                    04-01-1996   HQIC                          3828.122
#                          - 01-01-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.82e+05   1.21e-09   3.16e+14      0.000    3.82e+05    3.82e+05
# ar.L1          1.4570      0.043     33.997      0.000       1.373       1.541
# ar.L2         -0.9764      0.078    -12.531      0.000      -1.129      -0.824
# ar.L3          1.3968      0.079     17.630      0.000       1.241       1.552
# ar.L4         -0.8776      0.047    -18.760      0.000      -0.969      -0.786
# ma.L1          1.4087      0.054     25.962      0.000       1.302       1.515
# ma.L2          1.8870      0.089     21.268      0.000       1.713       2.061
# ma.L3          1.1475      0.079     14.515      0.000       0.993       1.302
# ma.L4          0.5946      0.058     10.310      0.000       0.482       0.708
# sigma2      5.182e+05   3.47e-08    1.5e+13      0.000    5.18e+05    5.18e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.36   Jarque-Bera (JB):               146.35
# Prob(Q):                              0.12   Prob(JB):                         0.00
# Heteroskedasticity (H):              21.82   Skew:                             0.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.66e+30. Standard errors may be unstable.

# %%
prediction_model(arima_model= arima_model)

# %% [markdown]
# ### Sarimax Model

# %%
def ts_performance(data, pdq, pdqs, m_type):
    '''
    data : data input
    pdq : (p,d,q)
    pdqs : (p,d,q,s)
    m_type : String indicating how parameters were selected
    '''
    model = SARIMAX(data, order=pdq, seasonal_order=pdqs,
                    enforce_stationarity=False, enforce_invertibility=False).fit()
    
    print(f'\033[1m{m_type}\033[0m\n') 
    print(model.mle_retvals)
    print(f'{model.summary()}\n')
    fig = model.plot_diagnostics(figsize=(16, 10))
    fig.suptitle(m_type, fontsize=16)
    fig.savefig('final_plots/diagnostics.png')

    return model

sari_model_aic = ts_performance(train, (0, 2, 2), (1, 2, 2, 12), 'lowest AIC') # lowest AIC
sari_model_rmse = ts_performance(train, (2, 1, 1), (2, 1, 0, 12), 'lowest RMSE') # lowest RMSE
# sari_model = ts_performance(train, (2, 1, 1), (2, 1, 0, 12), 'lowest Average') # best of both

final_model = ts_performance(limited_df, (2, 1, 1), (2, 1, 0, 12), 'Final Model')
# Out:
# lowest AIC
#
# {'fopt': 6.68705628447581, 'gopt': array([-1.79278814e-06,  1.68984826e-06, -5.70974379e-06, -2.44773091e-06,
#         4.67421657e-06, -2.13162821e-09]), 'fcalls': 364, 'warnflag': 0, 'converged': True, 'iterations': 44}
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                 MedianHousingSales   No. Observations:                  238
# Model:             SARIMAX(0, 2, 2)x(1, 2, 2, 12)   Log Likelihood               -1591.519
# Date:                            Fri, 12 May 2023   AIC                           3195.039
# Time:                                    11:40:15   BIC                           3214.361
# Sample:                                04-01-1996   HQIC                          3202.870
#                                      - 01-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.8447      0.063     13.415      0.000       0.721       0.968
# ma.L2          0.4071      0.065      6.243      0.000       0.279       0.535
# ar.S.L12      -0.7692      0.097     -7.928      0.000      -0.959      -0.579
# ma.S.L12      -0.3382      0.096     -3.512      0.000      -0.527      -0.149
# ma.S.L24       0.0492      0.075      0.653      0.514      -0.098       0.197
# sigma2      1.667e+06   1.28e+05     13.054      0.000    1.42e+06    1.92e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.19   Jarque-Bera (JB):                31.62
# Prob(Q):                              0.28   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.63   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# lowest RMSE
#
# {'fopt': 6.911761707474056, 'gopt': array([ 4.80540052e-06,  3.38218342e-07,  1.28306255e-06, -3.30837580e-06,
#         3.29611893e-06, -2.13162821e-09]), 'fcalls': 301, 'warnflag': 0, 'converged': True, 'iterations': 37}
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                  MedianHousingSales   No. Observations:                  238
# Model:             SARIMAX(2, 1, 1)x(2, 1, [], 12)   Log Likelihood               -1644.999
# Date:                             Fri, 12 May 2023   AIC                           3301.999
# Time:                                     11:40:18   BIC                           3321.758
# Sample:                                 04-01-1996   HQIC                          3309.996
#                                       - 01-01-2016
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4316      0.070     20.372      0.000       1.294       1.569
# ar.L2         -0.5079      0.067     -7.577      0.000      -0.639      -0.377
# ma.L1          0.1821      0.073      2.486      0.013       0.039       0.326
# ar.S.L12      -0.8146      0.066    -12.412      0.000      -0.943      -0.686
# ar.S.L24      -0.2111      0.077     -2.754      0.006      -0.361      -0.061
# sigma2      8.824e+05   6.57e+04     13.423      0.000    7.54e+05    1.01e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):                40.46
# Prob(Q):                              0.43   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.34   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Final Model
#
# {'fopt': 7.1684446832242, 'gopt': array([ 3.82005538e-07, -3.38591377e-06,  7.98756616e-06, -4.21094271e-06,
#         6.48903153e-07,  1.77635684e-10]), 'fcalls': 308, 'warnflag': 0, 'converged': True, 'iterations': 42}
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                  MedianHousingSales   No. Observations:                  265
# Model:             SARIMAX(2, 1, 1)x(2, 1, [], 12)   Log Likelihood               -1899.638
# Date:                             Fri, 12 May 2023   AIC                           3811.276
# Time:                                     11:40:21   BIC                           3831.799
# Sample:                                 04-01-1996   HQIC                          3819.558
#                                       - 04-01-2018
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3486      0.061     22.091      0.000       1.229       1.468
# ar.L2         -0.4253      0.059     -7.259      0.000      -0.540      -0.310
# ma.L1          0.1529      0.043      3.554      0.000       0.069       0.237
# ar.S.L12      -0.9098      0.053    -17.173      0.000      -1.014      -0.806
# ar.S.L24      -0.4544      0.054     -8.371      0.000      -0.561      -0.348
# sigma2      1.161e+06   8.65e+04     13.412      0.000    9.91e+05    1.33e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.91   Jarque-Bera (JB):                36.70
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.40   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
def prediction_model(**kwargs):
    fig, ax = plt.subplots(figsize=(20,12))
    ax.plot(train, label='train')
    ax.plot(test, label='test')
    
    for label, model in kwargs.items():
        y_hat_test = model.predict(start=test.index[0], end=test.index[-1],typ='levels')
        ax.plot(y_hat_test, label=label)
        
    ax.set_xlabel('Year', fontsize=20)
    ax.set_ylabel('Median House Sales ($)', fontsize=20)
    ax.set_title('Median House Sales each Year', fontsize=20)
    ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
    ax.tick_params(axis='both', which='major', labelsize=15);
    plt.legend();
#     plt.savefig('final_plots/full_prediction.png',dpi=300)

# %%
prediction_model(sari_model_aic=sari_model_aic, sari_model_rmse=sari_model_rmse)

# %%
prediction_model(sari_model_rmse=sari_model_rmse)

# %% [markdown]
# <a id='Forecast'></a>
# # Forecast

# %%
forecast = final_model.forecast(steps=76)
fig, ax = plt.subplots(figsize=(20,12))
# ax.plot(train, label='train')

ax.plot(limited_df, label='test')
ax.plot(forecast, label='test_pred')

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Median House Sales', fontsize=20)
ax.set_title('Forecasting Median House Sales each Year', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

plt.legend();
# plt.savefig('final_plots/forcasted_1996.png',dpi=300)

# %%
future = final_model.get_forecast(steps=24)
future_conf = future.conf_int()

ax = limited_df.plot(label='Reality', figsize=(20, 12), color='b')

future.predicted_mean.plot(label='Forecast', ax=ax, color='r')

ax.fill_between(future_conf.index,
                future_conf.iloc[:, 0],
                future_conf.iloc[:, 1], color='grey', alpha=.3)

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Median House Sales ($)', fontsize=20)
ax.set_title('Median House Sales each Year', fontsize=20)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
ax.tick_params(axis='both', which='major', labelsize=15);


plt.legend();

# %%
# zooming in
future = final_model.get_forecast(steps=24)
future_conf = future.conf_int()
df_2016 = limited_df[limited_df.index > '2015-12-01']

ax = df_2016.plot(label='Reality', figsize=(20, 12), color='b')

future.predicted_mean.plot(label='Forecast', ax=ax, color='r')

ax.fill_between(future_conf.index,
                future_conf.iloc[:, 0],
                future_conf.iloc[:, 1], color='grey', alpha=.3)

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Median House Sales ($)', fontsize=20)
ax.set_title('Median House Sales each Year Forecast', fontsize=20)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
ax.tick_params(axis='both', which='major', labelsize=15);


plt.legend();
plt.savefig('final_plots/forcasted_2015.png',dpi=300)

# %% [markdown]
# <a id='ROI'></a>
# ## ROI

# %%
dc_zipcode = dc_df.groupby('zipcode').mean()
dc_date = dc_df.groupby('Date').mean()

# %%
fig, ax = plt.subplots(figsize=(20,12))
dc_zipcode.sort_values(by='PercentChange', inplace=True)
colors = ['grey']*13 +['red']*5
# ax.plot(train, label='train')
ax.bar(dc_zipcode['PercentChange'].index.astype(str), dc_zipcode['PercentChange'].values, color=colors)
# ax.plot(y_hat_train, label='train_pred')

ax.set_xlabel('Year',fontsize=20)
ax.set_ylabel('ROI', fontsize=20)
ax.set_title('Mean ROI per Zipcode over 22 Years', fontsize=20)
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0%}'))
ax.tick_params(axis='both', which='major', labelsize=15);


plt.savefig('final_plots/percentchange_bar.png',dpi=300)

# %%
fig, ax = plt.subplots(figsize=(20,12))
dc_zipcode.sort_values(by='22_year_pct_change', inplace=True)
colors = ['grey']*13 +['red']*5
# ax.plot(train, label='train')
ax.bar(dc_zipcode['22_year_pct_change'].index.astype(str), dc_zipcode['22_year_pct_change'].values, color=colors)
# ax.plot(y_hat_train, label='train_pred')

ax.set_xlabel('Year', fontsize=15)
ax.set_ylabel('ROI', fontsize=15)
ax.set_title('ROI over from 1996-2018 Year', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15);

plt.savefig('final_plots/percentchange_bar_96-18.png',dpi=300)

# %%
fig, ax = plt.subplots(figsize=(20,12))
# ax.plot(train, label='train')
ax.plot(dc_date['PercentChange'])
# ax.plot(y_hat_train, label='train_pred')

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Percent Change', fontsize=20)
ax.set_title('Percent Change in house sales each Year', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15);


plt.savefig('final_plots/percentchange.png',dpi=300)

# %% [markdown]
# <a id='interpreting-results'></a>
# ## Interpreting Results

# %% [markdown]
# <a id='recommendations'></a>
# ## Recommendations

# %% [markdown]
# <a id='next-steps'></a>
# ## Next Steps

# %% [markdown]
# <a id='repository-file-structure'></a>
# ## Repository File Structure
